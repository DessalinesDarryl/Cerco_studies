# %%
import sys
import os

# Ajoute le dossier src/ au path si besoin
sys.path.append(os.path.abspath("../src"))

from cohort import load_patient_groups, group_edf_files_by_pathology

# Chargement de la feuille 3 du fichier Excel
excel_path = "../data/nv_patientsRBD_identifiants.xlsx"
df, group_map = load_patient_groups(excel_path, sheet_index=2)

# Aperçu des premières lignes
df.head()
# Out:
#   identifiant_edf extrait/entier             Nom Prénom Pathologie  \
# 0             IB1        extrait        Ibarki Mohamed        PARK
# 1             HA6        extrait    Hachchadi Abdesslam       PARK
# 2             GF7       extrait          Garoby Fernand        AMS
# 3            GMT9       extrait   Girault Marie-Thérèse        AMS
# 4            DF13       extrait           Domon Fabrice        AMS
#
#   Pathologie_group          label Sexe Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0     syn_patients  synucleopathy    M        NaN        NaN        NaN
# 1     syn_patients  synucleopathy    M        NaN        NaN        NaN
# 2     syn_patients  synucleopathy    M        NaN        NaN        NaN
# 3     syn_patients  synucleopathy    F        NaN        NaN        NaN
# 4     syn_patients  synucleopathy    M        NaN        NaN        NaN
#
#   Unnamed: 10
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
group_map
# Out:
# {'IB1': 'synucleopathy',
#  'HA6': 'synucleopathy',
#  'GF7': 'synucleopathy',
#  'GMT9': 'synucleopathy',
#  'DF13': 'synucleopathy',
#  'MG16': 'autoimmune encephalitides',
#  'SA19': 'synucleopathy',
#  'RDJS20': 'tcspi',
#  'MJJ22': 'tcspi',
#  'FI23': 'tcspi',
#  'SA24': 'tcspi',
#  'FC25': 'tcspi',
#  'MN26': 'narcolepsy',
#  'MA27': 'tcspi',
#  'CD28': 'tcspi',
#  'MHTK39': 'narcolepsy',
#  'LJ41': 'narcolepsy',
#  'RJ42': 'narcolepsy',
#  'NAL43': 'narcolepsy',
#  'BDRE44': 'narcolepsy',
#  'FP52': 'tcspi',
#  'CJP53': 'tcspi',
#  'GG58': 'tcspi',
#  'BO60': 'synucleopathy',
#  'CS68': 'synucleopathy',
#  'GC76': 'synucleopathy',
#  'GE79': 'synucleopathy',
#  'IM83': 'synucleopathy',
#  'LCM89': 'synucleopathy',
#  'LY90': 'synucleopathy',
#  'SJC98': 'synucleopathy',
#  'SE99': 'synucleopathy',
#  'RB103': 'narcolepsy',
#  'GS105': 'tcspi',
#  'GR108': 'tcspi',
#  'MM109': 'tcspi',
#  'DA110': 'tcspi',
#  'GX111': 'tcspi',
#  'DSJ112': 'tcspi',
#  'KH113': 'autoimmune encephalitides',
#  'BB114': 'synucleopathy',
#  'BMF115': 'tcspi',
#  'KG117': 'tcspi',
#  'DLL119': 'tcspi',
#  'CB125': 'narcolepsy',
#  'LF126': 'tcspi',
#  'TJ127': 'autoimmune encephalitides',
#  'MS128': 'synucleopathy',
#  'AE129': 'narcolepsy',
#  'EF130': 'tcspi',
#  'CS131': 'tcspi',
#  'MRM132': 'tcspi',
#  'PF133': 'tcspi',
#  'SD134': 'tcspi',
#  'ML135': 'synucleopathy',
#  'DI136': 'tcspi',
#  'DJ137': 'tcspi',
#  'BJ138': 'tcspi',
#  'PA139': 'synucleopathy',
#  'PJC140': 'tcspi',
#  'JP141': 'tcspi',
#  'TM142': 'synucleopathy',
#  'MN143': 'tcspi',
#  'FP144': 'tcspi',
#  'TO145': 'tcspi',
#  'RH146': 'tcspi',
#  'CS147': 'narcolepsy',
#  'RJP148': 'synucleopathy',
#  'VJ149': 'tcspi',
#  'MP150': 'tcspi',
#  'TM151': 'synucleopathy',
#  'BA152': 'synucleopathy',
#  'PJL153': 'tcspi',
#  'MC154': 'tcspi',
#  'CP155': 'tcspi',
#  'RG156': 'synucleopathy',
#  'NGA157': 'synucleopathy',
#  'RD158': 'synucleopathy',
#  'CJL159': 'autoimmune encephalitides',
#  'MFJ160': 'autoimmune encephalitides',
#  'CM161': 'tcspi',
#  'LS162': 'tcspi',
#  'GH163': 'synucleopathy',
#  'CD164': 'tcspi',
#  'CB165': 'tcspi',
#  'AN166': 'autoimmune encephalitides',
#  'HG167': 'narcolepsy',
#  'TLM168': 'narcolepsy',
#  'CA169': 'tcspi',
#  'GD170': 'synucleopathy',
#  'BA171': 'synucleopathy',
#  'SJP172': 'synucleopathy',
#  'JB173': 'autoimmune encephalitides',
#  'DA174': 'tcspi',
#  'CC175': 'tcspi',
#  'SB176': 'tcspi',
#  'JLJ177': 'tcspi',
#  'SB178': 'autoimmune encephalitides',
#  'IS179': 'tcspi',
#  'AD180': 'synucleopathy',
#  'BF181': 'synucleopathy',
#  'VA182': 'synucleopathy',
#  'LM183': 'synucleopathy',
#  'DBJ184': 'autoimmune encephalitides',
#  'BP185': 'synucleopathy',
#  'PB186': 'synucleopathy'}
